# %% [markdown]
# # Seaborn
#
# ## Import Seaborn as sns

# %%
import seaborn as sns

# %%
#Below command will allow us to use visualizations inline
# %matplotlib inline

# %%
dmd=sns.load_dataset('diamonds')

# %%
dmd.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
# Plot distribution of single variable
dist_Y = sns.distplot(dmd['carat'])
print(dist_Y)
# Out:
# C:\Users\Rupesh\AppData\Local\Temp\ipykernel_10300\646194560.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   dist_Y = sns.distplot(dmd['carat'])
# Axes(0.125,0.11;0.775x0.77)

# %%
sns.distplot(dmd['carat'],kde=False,bins=30)
# Out:
# C:\Users\Rupesh\AppData\Local\Temp\ipykernel_6140\1953953276.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dmd['carat'],kde=False,bins=30)
# <Axes: xlabel='carat'>

# %%
sns.jointplot(x='carat',y='price',data=dmd,kind='scatter')

# %%
sns.jointplot(x='carat',y='price',data=dmd,kind='reg')

# %%
sns.pairplot(dmd)

# %%
 sns.rugplot(dmd['price'])
# Out:
# <Axes: xlabel='price'>

# %% [markdown]
# ## Categorical Plots

# %%
# Barplot

sns.barplot(x='color',y='price',data=dmd)
# Out:
# <Axes: xlabel='color', ylabel='price'>

# %%
#The difference between countplot and barplot is that countplot explicitly counts the number of occurrences.
## Count plot
sns.countplot(x='color',data=dmd)
# Out:
# <Axes: xlabel='color', ylabel='count'>

# %%
## Box plot

sns.boxplot(x='color',y='price',data=dmd,palette='rainbow')
# Out:
# <Axes: xlabel='color', ylabel='price'>

# %%
## Violinplot

sns.violinplot(x='color',y='price',data=dmd,palette='rainbow')
# Out:
# <Axes: xlabel='color', ylabel='price'>

# %%
## Strip Plot

sns.stripplot(x='color',y='price',data=dmd,palette='rainbow')
# Out:
# C:\Users\Rupesh\AppData\Local\Temp\ipykernel_6140\3164591220.py:3: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(x='color',y='price',data=dmd,palette='rainbow')
# <Axes: xlabel='color', ylabel='price'>

# %% [markdown]
# # MatrixPlots

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
dms=sns.load_dataset('diamonds')

# %%
dms.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
dmd.corr()
# Out:
# C:\Users\Rupesh\AppData\Local\Temp\ipykernel_6140\1604993656.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dmd.corr()
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.028224  0.181618  0.921591  0.975094  0.951722  0.953387
# depth  0.028224  1.000000 -0.295779 -0.010647 -0.025289 -0.029341  0.094924
# table  0.181618 -0.295779  1.000000  0.127134  0.195344  0.183760  0.150929
# price  0.921591 -0.010647  0.127134  1.000000  0.884435  0.865421  0.861249
# x      0.975094 -0.025289  0.195344  0.884435  1.000000  0.974701  0.970772
# y      0.951722 -0.029341  0.183760  0.865421  0.974701  1.000000  0.952006
# z      0.953387  0.094924  0.150929  0.861249  0.970772  0.952006  1.000000

# %%
#The corr() function gives the matrix form to correlation data.
#Below command generates the heatmap.

sns.heatmap(dmd.corr())
# Out:
# C:\Users\Rupesh\AppData\Local\Temp\ipykernel_6140\1761420002.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(dmd.corr())
# <Axes: >

# %%
flightdata=sns.load_dataset('flights')
flightdata.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
# Pivot data - the total number of passengers for each month of the year.

flightdata.pivot_table(values='passengers',index='month',columns='year')
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
sns.heatmap(flightdata.pivot_table(values='passengers',index='month',columns='year'))
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# ## Cluster Map

# %%
sns.clustermap(flightdata.pivot_table(values='passengers',index='month',columns='year'))

# %% [markdown]
# ## Regression Plot

# %%
dms.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.lmplot(x='carat',y='price',data=dmd)
